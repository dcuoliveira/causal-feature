# %%
import numpy as np
import pandas as pd
from glob import glob
import os

# %%
trends_path = os.path.join('data','daily_trend',"*.csv")
daily_dfs_path =  glob(trends_path)
daily_dfs = [pd.read_csv(path) for path in daily_dfs_path]
daily_dfs_names = [i.split("/")[2] for i in daily_dfs_path]
daily_dfs_names = [i.split(".")[0] for i in daily_dfs_names]

trends_df = []
for name, df in zip(daily_dfs_names, daily_dfs):
    path = os.path.join('data','2010_daily_trend',"{}.csv".format(name))
    df.date = pd.to_datetime(df.date)
    df = df.set_index("date")
    df = df[:"2010-01-01"].reset_index()
    cdr_df = pd.read_csv(path)
    cdr_df.date = pd.to_datetime(cdr_df.date)
    combined_df = pd.concat([df, cdr_df]).groupby("date").mean()
    combined_df = combined_df.reset_index()
    new_path = os.path.join('data','result_daily_trend',"{}.csv".format(name))
    combined_df.to_csv(new_path)

# %%
combined_df.reset_index()
# Out:
#            date  ministry  google  isPartial
# 0    2004-01-01       3.0    38.0      False
# 1    2004-01-02       3.0    35.0      False
# 2    2004-01-03       5.0    36.0      False
# 3    2004-01-04       3.0    34.0      False
# 4    2004-01-05       6.0    36.0      False
# ...         ...       ...     ...        ...
# 6047 2020-07-22       0.0    35.0      False
# 6048 2020-07-23       0.0    34.0      False
# 6049 2020-07-24       0.0    32.0      False
# 6050 2020-07-25       0.0    26.0      False
# 6051 2020-07-26       0.0    27.0      False
#
# [6052 rows x 4 columns]

# %%
i = 90
print(daily_dfs_names[i])
trends_df[i][daily_dfs_names[i]].rolling(40).mean().plot();
# Out:
# carolina

# %%
daily_dfs_names
# Out:
# ['investment',
#  'health',
#  'committee',
#  'invest',
#  'lifestyle',
#  'elections',
#  'debt',
#  'judge',
#  'house',
#  'market',
#  'cash',
#  'fine',
#  'bonds',
#  'georgia',
#  'greed',
#  'conty',
#  'illinois',
#  'massachusetts',
#  'kitchen',
#  'leverage',
#  'earnings',
#  'governor',
#  'car',
#  'minister',
#  'dow jones',
#  'BUY AND HOLD',
#  'economics',
#  'metals',
#  'freedom',
#  'justice',
#  'food',
#  'crisis',
#  'kentucky',
#  'arts',
#  'DOW JONES',
#  'movement',
#  'district',
#  'election',
#  'hedge',
#  'money',
#  'gains',
#  'forex',
#  'consume',
#  'markets',
#  'growth',
#  'chance',
#  'financial',
#  'council',
#  'crash',
#  'labor',
#  'color',
#  'democratic',
#  'environment',
#  'holiday',
#  'earths',
#  'happy',
#  'law',
#  'government',
#  'fun',
#  'gold',
#  'home',
#  'federal',
#  'college',
#  'fed',
#  'credit',
#  'movie',
#  'default',
#  'members',
#  'finance',
#  'cancer',
#  'case',
#  'consumption',
#  'bubble',
#  'missouri',
#  'conflict',
#  'loss',
#  'culture',
#  'economy',
#  'headlines',
#  'inflation',
#  'legal',
#  'garden',
#  'derivatives',
#  'gain',
#  'buy',
#  'energy',
#  'elected',
#  'dividend',
#  'housing',
#  'banking',
#  'carolina',
#  'act',
#  'fond',
#  'marriage',
#  'court',
#  'ministry']

# %%
pd.concat([df, cdr_df]).groupby("date").mean()
# Out:
#             ministry  google  isPartial
# date
# 2004-01-01       3.0    38.0      False
# 2004-01-02       3.0    35.0      False
# 2004-01-03       5.0    36.0      False
# 2004-01-04       3.0    34.0      False
# 2004-01-05       6.0    36.0      False
# ...              ...     ...        ...
# 2020-07-22       0.0    35.0      False
# 2020-07-23       0.0    34.0      False
# 2020-07-24       0.0    32.0      False
# 2020-07-25       0.0    26.0      False
# 2020-07-26       0.0    27.0      False
#
# [6052 rows x 3 columns]
