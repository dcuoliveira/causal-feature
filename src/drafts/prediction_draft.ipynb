# %%
import pandas as pd
import numpy as np
from data_mani.utils import merge_market_and_gtrends
from tqdm import tqdm
from sklearn.ensemble import RandomForestRegressor
from prediction.util import new_r2, add_shift
from sklearn.model_selection import TimeSeriesSplit, RandomizedSearchCV
from sklearn.metrics import make_scorer
from IPython.display import display, HTML
from glob import glob

# %%
names = glob("data/index/spx/*.csv")
names = [n for n in names if n.find("(1)")<0]
names.sort()

# %%
names
# Out:
# ['data/index/spx/0111145D UN Equity.csv',
#  'data/index/spx/0202445Q UN Equity.csv',
#  'data/index/spx/0203524D UN Equity.csv',
#  'data/index/spx/0226226D UN Equity.csv',
#  'data/index/spx/0544749D UN Equity.csv',
#  'data/index/spx/0574018D UN Equity.csv',
#  'data/index/spx/0772031D UN Equity.csv',
#  'data/index/spx/0848680D UN Equity.csv',
#  'data/index/spx/0867887D UN Equity.csv',
#  'data/index/spx/0867887D US Equity.csv',
#  'data/index/spx/0910150D US Equity.csv',
#  'data/index/spx/0948669D UN Equity.csv',
#  'data/index/spx/0961514D UN Equity.csv',
#  'data/index/spx/0964591D UQ Equity.csv',
#  'data/index/spx/0964591D UW Equity.csv',
#  'data/index/spx/1028411Q UN Equity.csv',
#  'data/index/spx/1086832D UN Equity.csv',
#  'data/index/spx/1255173D UN Equity.csv',
#  'data/index/spx/1255459D UW Equity.csv',
#  'data/index/spx/1280712D UQ Equity.csv',
#  'data/index/spx/1280712D UW Equity.csv',
#  'data/index/spx/1281683D UN Equity.csv',
#  'data/index/spx/1284849D UN Equity.csv',
#  'data/index/spx/1288453D UW Equity.csv',
#  'data/index/spx/1288652D US Equity.csv',
#  'data/index/spx/1293405D UN Equity.csv',
#  'data/index/spx/1312089D UN Equity.csv',
#  'data/index/spx/1317355D UN Equity.csv',
#  'data/index/spx/1431816D UN Equity.csv',
#  'data/index/spx/1431816D UW Equity.csv',
#  'data/index/spx/1436513D UN Equity.csv',
#  'data/index/spx/1437355D US Equity.csv',
#  'data/index/spx/1448062D UN Equity.csv',
#  'data/index/spx/1448062D UQ Equity.csv',
#  'data/index/spx/1448062D UW Equity.csv',
#  'data/index/spx/1500785D UN Equity.csv',
#  'data/index/spx/1518855D US Equity.csv',
#  'data/index/spx/1519128D UA Equity.csv',
#  'data/index/spx/1519128D UQ Equity.csv',
#  'data/index/spx/1519128D UW Equity.csv',
#  'data/index/spx/1520415D UN Equity.csv',
#  'data/index/spx/1524867D UN Equity.csv',
#  'data/index/spx/1528159D UN Equity.csv',
#  'data/index/spx/1539941D UN Equity.csv',
#  'data/index/spx/1541931D UA Equity.csv',
#  'data/index/spx/1541931D UQ Equity.csv',
#  'data/index/spx/1541931D UW Equity.csv',
#  'data/index/spx/1566019D UN Equity.csv',
#  'data/index/spx/1649858D UN Equity.csv',
#  'data/index/spx/1649858D UQ Equity.csv',
#  'data/index/spx/1649858D UW Equity.csv',
#  'data/index/spx/1654539D UN Equity.csv',
#  'data/index/spx/1683351D UQ Equity.csv',
#  'data/index/spx/1683997D UQ Equity.csv',
#  'data/index/spx/1683997D UW Equity.csv',
#  'data/index/spx/1684442D UN Equity.csv',
#  'data/index/spx/1697067D UN Equity.csv',
#  'data/index/spx/1699947D US Equity.csv',
#  'data/index/spx/1704453D UN Equity.csv',
#  'data/index/spx/1715651D UN Equity.csv',
#  'data/index/spx/1719868D UN Equity.csv',
#  'data/index/spx/1746513D UQ Equity.csv',
#  'data/index/spx/1746513D UW Equity.csv',
#  'data/index/spx/1752754D UN Equity.csv',
#  'data/index/spx/1799685D UN Equity.csv',
#  'data/index/spx/1806854D UN Equity.csv',
#  'data/index/spx/1810430D UN Equity.csv',
#  'data/index/spx/1812212D UW Equity.csv',
#  'data/index/spx/1822785D UN Equity.csv',
#  'data/index/spx/1825471D UN Equity.csv',
#  'data/index/spx/1831877D UN Equity.csv',
#  'data/index/spx/1831877D US Equity.csv',
#  'data/index/spx/1837572D UN Equity.csv',
#  'data/index/spx/1844053D US Equity.csv',
#  'data/index/spx/1856613D UN Equity.csv',
#  'data/index/spx/1858968D UN Equity.csv',
#  'data/index/spx/2307532Q UQ Equity.csv',
#  'data/index/spx/2307532Q UW Equity.csv',
#  'data/index/spx/2641504Q UN Equity.csv',
#  'data/index/spx/2676187Q UQ Equity.csv',
#  'data/index/spx/2727195Q UN Equity.csv',
#  'data/index/spx/2942331Q UN Equity.csv',
#  'data/index/spx/2968900Q UN Equity.csv',
#  'data/index/spx/297504Q UN Equity.csv',
#  'data/index/spx/2987536Q UN Equity.csv',
#  'data/index/spx/2999130Q UN Equity.csv',
#  'data/index/spx/3022239Q UN Equity.csv',
#  'data/index/spx/3026360Q UN Equity.csv',
#  'data/index/spx/3029830Q UQ Equity.csv',
#  'data/index/spx/3080867Q UN Equity.csv',
#  'data/index/spx/3133754Q UN Equity.csv',
#  'data/index/spx/3153670Q UQ Equity.csv',
#  'data/index/spx/3286728Q UN Equity.csv',
#  'data/index/spx/3362726Q UN Equity.csv',
#  'data/index/spx/3393199Q UN Equity.csv',
#  'data/index/spx/3403545Q UN Equity.csv',
#  'data/index/spx/3414924Q US Equity.csv',
#  'data/index/spx/3423152Q UN Equity.csv',
#  'data/index/spx/3517233Q UN Equity.csv',
#  'data/index/spx/355488Q UN Equity.csv',
#  'data/index/spx/3605818Q UN Equity.csv',
#  'data/index/spx/3621240Q UN Equity.csv',
#  'data/index/spx/3692470Q UN Equity.csv',
#  'data/index/spx/4621824Q UN Equity.csv',
#  'data/index/spx/502466Q US Equity.csv',
#  'data/index/spx/519239Q UN Equity.csv',
#  'data/index/spx/519239Q UQ Equity.csv',
#  'data/index/spx/5656565D UN Equity.csv',
#  'data/index/spx/605018Q UN Equity.csv',
#  'data/index/spx/605555Q UN Equity.csv',
#  'data/index/spx/653707Q UN Equity.csv',
#  'data/index/spx/723588Q UN Equity.csv',
#  'data/index/spx/748957Q UN Equity.csv',
#  'data/index/spx/764144Q UN Equity.csv',
#  'data/index/spx/8206908Q UQ Equity.csv',
#  'data/index/spx/8206908Q UW Equity.csv',
#  'data/index/spx/8277831Q UN Equity.csv',
#  'data/index/spx/8394653Q UN Equity.csv',
#  'data/index/spx/929530Q UN Equity.csv',
#  'data/index/spx/945852Q UN Equity.csv',
#  'data/index/spx/987200Q UN Equity.csv',
#  'data/index/spx/9876544D UN Equity.csv',
#  'data/index/spx/9876549D UN Equity.csv',
#  'data/index/spx/9876566D UN Equity.csv',
#  'data/index/spx/9995522D UN Equity.csv',
#  'data/index/spx/A UN Equity.csv',
#  'data/index/spx/AA UN Equity.csv',
#  'data/index/spx/AAL UW Equity.csv',
#  'data/index/spx/AAMRQ UN Equity.csv',
#  'data/index/spx/AAP UN Equity.csv',
#  'data/index/spx/AAPL UQ Equity.csv',
#  'data/index/spx/AAPL UW Equity.csv',
#  'data/index/spx/ABBV UN Equity.csv',
#  'data/index/spx/ABC UN Equity.csv',
#  'data/index/spx/ABKFQ UN Equity.csv',
#  'data/index/spx/ABMD UW Equity.csv',
#  'data/index/spx/ABT UN Equity.csv',
#  'data/index/spx/ACAS UW Equity.csv',
#  'data/index/spx/ACN UN Equity.csv',
#  'data/index/spx/ADBE UQ Equity.csv',
#  'data/index/spx/ADBE UW Equity.csv',
#  'data/index/spx/ADI UN Equity.csv',
#  'data/index/spx/ADI UW Equity.csv',
#  'data/index/spx/ADM UN Equity.csv',
#  'data/index/spx/ADNT UN Equity.csv',
#  'data/index/spx/ADP UN Equity.csv',
#  'data/index/spx/ADP UW Equity.csv',
#  'data/index/spx/ADS UN Equity.csv',
#  'data/index/spx/ADSK UQ Equity.csv',
#  'data/index/spx/ADSK UW Equity.csv',
#  'data/index/spx/AEE UN Equity.csv',
#  'data/index/spx/AEP UN Equity.csv',
#  'data/index/spx/AEP UW Equity.csv',
#  'data/index/spx/AES UN Equity.csv',
#  'data/index/spx/AET UN Equity.csv',
#  'data/index/spx/AFL UN Equity.csv',
#  'data/index/spx/AGN UN Equity.csv',
#  'data/index/spx/AIG UN Equity.csv',
#  'data/index/spx/AIRC UN Equity.csv',
#  'data/index/spx/AIV UN Equity.csv',
#  'data/index/spx/AIZ UN Equity.csv',
#  'data/index/spx/AJG UN Equity.csv',
#  'data/index/spx/AKAM UW Equity.csv',
#  'data/index/spx/AKS UN Equity.csv',
#  'data/index/spx/ALB UN Equity.csv',
#  'data/index/spx/ALGN UW Equity.csv',
#  'data/index/spx/ALK UN Equity.csv',
#  'data/index/spx/ALL UN Equity.csv',
#  'data/index/spx/ALLE UN Equity.csv',
#  'data/index/spx/ALXN UW Equity.csv',
#  'data/index/spx/AMAT UQ Equity.csv',
#  'data/index/spx/AMAT UW Equity.csv',
#  'data/index/spx/AMCC UQ Equity.csv',
#  'data/index/spx/AMCR UN Equity.csv',
#  'data/index/spx/AMD UN Equity.csv',
#  'data/index/spx/AMD UR Equity.csv',
#  'data/index/spx/AMD UW Equity.csv',
#  'data/index/spx/AME UN Equity.csv',
#  'data/index/spx/AMG UN Equity.csv',
#  'data/index/spx/AMGN UQ Equity.csv',
#  'data/index/spx/AMGN UW Equity.csv',
#  'data/index/spx/AMP UN Equity.csv',
#  'data/index/spx/AMT UN Equity.csv',
#  'data/index/spx/AMZN UQ Equity.csv',
#  'data/index/spx/AMZN UW Equity.csv',
#  'data/index/spx/AN UN Equity.csv',
#  'data/index/spx/ANDV UN Equity.csv',
#  'data/index/spx/ANDV US Equity.csv',
#  'data/index/spx/ANDW UQ Equity.csv',
#  'data/index/spx/ANDW UW Equity.csv',
#  'data/index/spx/ANET UN Equity.csv',
#  'data/index/spx/ANF UN Equity.csv',
#  'data/index/spx/ANRZQ UN Equity.csv',
#  'data/index/spx/ANSS UW Equity.csv',
#  'data/index/spx/ANTM UN Equity.csv',
#  'data/index/spx/AON UN Equity.csv',
#  'data/index/spx/AOS UN Equity.csv',
#  'data/index/spx/APA UN Equity.csv',
#  'data/index/spx/APA UW Equity.csv',
#  'data/index/spx/APC UN Equity.csv',
#  'data/index/spx/APD UN Equity.csv',
#  'data/index/spx/APH UN Equity.csv',
#  'data/index/spx/APOL UQ Equity.csv',
#  'data/index/spx/APOL UW Equity.csv',
#  'data/index/spx/APTV UN Equity.csv',
#  'data/index/spx/ARE UN Equity.csv',
#  'data/index/spx/ARG UN Equity.csv',
#  'data/index/spx/ARNC UN Equity.csv',
#  'data/index/spx/ASH UN Equity.csv',
#  'data/index/spx/ASIX UN Equity.csv',
#  'data/index/spx/ATGE UN Equity.csv',
#  'data/index/spx/ATI UN Equity.csv',
#  'data/index/spx/ATO UN Equity.csv',
#  'data/index/spx/ATVI UW Equity.csv',
#  'data/index/spx/AVB UN Equity.csv',
#  'data/index/spx/AVGO UW Equity.csv',
#  'data/index/spx/AVP UN Equity.csv',
#  'data/index/spx/AVY UN Equity.csv',
#  'data/index/spx/AW UN Equity.csv',
#  'data/index/spx/AWE UN Equity.csv',
#  'data/index/spx/AWK UN Equity.csv',
#  'data/index/spx/AXP UN Equity.csv',
#  'data/index/spx/AYE UN Equity.csv',
#  'data/index/spx/AYI UN Equity.csv',
#  'data/index/spx/AZO UN Equity.csv',
#  'data/index/spx/BA UN Equity.csv',
#  'data/index/spx/BAC UN Equity.csv',
#  'data/index/spx/BAX UN Equity.csv',
#  'data/index/spx/BBBY UQ Equity.csv',
#  'data/index/spx/BBBY UW Equity.csv',
#  'data/index/spx/BBY UN Equity.csv',
#  'data/index/spx/BC UN Equity.csv',
#  'data/index/spx/BCR UN Equity.csv',
#  'data/index/spx/BCR US Equity.csv',
#  'data/index/spx/BDK UN Equity.csv',
#  'data/index/spx/BDX UN Equity.csv',
#  'data/index/spx/BEN UN Equity.csv',
#  'data/index/spx/BF B UN Equity.csv',
#  'data/index/spx/BGEN UQ Equity.csv',
#  'data/index/spx/BHF UW Equity.csv',
#  'data/index/spx/BHI UN Equity.csv',
#  'data/index/spx/BIG UN Equity.csv',
#  'data/index/spx/BIIB UQ Equity.csv',
#  'data/index/spx/BIIB UW Equity.csv',
#  'data/index/spx/BIO UN Equity.csv',
#  'data/index/spx/BIVV UW Equity.csv',
#  'data/index/spx/BK UN Equity.csv',
#  'data/index/spx/BKNG UW Equity.csv',
#  'data/index/spx/BKR UN Equity.csv',
#  'data/index/spx/BLK UN Equity.csv',
#  'data/index/spx/BLL UN Equity.csv',
#  'data/index/spx/BLS UN Equity.csv',
#  'data/index/spx/BMC UN Equity.csv',
#  'data/index/spx/BMC UW Equity.csv',
#  'data/index/spx/BMS UN Equity.csv',
#  'data/index/spx/BMY UN Equity.csv',
#  'data/index/spx/BNI UN Equity.csv',
#  'data/index/spx/BOL UN Equity.csv',
#  'data/index/spx/BR UN Equity.csv',
#  'data/index/spx/BRCM UQ Equity.csv',
#  'data/index/spx/BRCM UW Equity.csv',
#  'data/index/spx/BRK B UN Equity.csv',
#  'data/index/spx/BRL UN Equity.csv',
#  'data/index/spx/BSX UN Equity.csv',
#  'data/index/spx/BTUUQ UN Equity.csv',
#  'data/index/spx/BWA UN Equity.csv',
#  'data/index/spx/BXLT UN Equity.csv',
#  'data/index/spx/BXP UN Equity.csv',
#  'data/index/spx/C UN Equity.csv',
#  'data/index/spx/CA UN Equity.csv',
#  'data/index/spx/CA UW Equity.csv',
#  'data/index/spx/CAG UN Equity.csv',
#  'data/index/spx/CAH UN Equity.csv',
#  'data/index/spx/CAM UN Equity.csv',
#  'data/index/spx/CAR UN Equity.csv',
#  'data/index/spx/CARR UN Equity.csv',
#  'data/index/spx/CAT UN Equity.csv',
#  'data/index/spx/CB UN Equity.csv',
#  'data/index/spx/CBE UN Equity.csv',
#  'data/index/spx/CBOE UF Equity.csv',
#  'data/index/spx/CBOE UW Equity.csv',
#  'data/index/spx/CBRE UN Equity.csv',
#  'data/index/spx/CCEP UN Equity.csv',
#  'data/index/spx/CCI UN Equity.csv',
#  'data/index/spx/CCL UN Equity.csv',
#  'data/index/spx/CCTYQ UN Equity.csv',
#  'data/index/spx/CDNS UW Equity.csv',
#  'data/index/spx/CDW UW Equity.csv',
#  'data/index/spx/CE UN Equity.csv',
#  'data/index/spx/CEG UN Equity.csv',
#  'data/index/spx/CELG UW Equity.csv',
#  'data/index/spx/CEPH UW Equity.csv',
#  'data/index/spx/CERN UW Equity.csv',
#  'data/index/spx/CF UN Equity.csv',
#  'data/index/spx/CFC UN Equity.csv',
#  'data/index/spx/CFG UN Equity.csv',
#  'data/index/spx/CFN UN Equity.csv',
#  'data/index/spx/CHD UN Equity.csv',
#  'data/index/spx/CHKAQ UN Equity.csv',
#  'data/index/spx/CHRW UW Equity.csv',
#  'data/index/spx/CHTR UW Equity.csv',
#  'data/index/spx/CHX UN Equity.csv',
#  'data/index/spx/CI UN Equity.csv',
#  'data/index/spx/CIEN UA Equity.csv',
#  'data/index/spx/CIEN UQ Equity.csv',
#  'data/index/spx/CIEN UW Equity.csv',
#  'data/index/spx/CIN UN Equity.csv',
#  'data/index/spx/CINF UQ Equity.csv',
#  'data/index/spx/CINF UW Equity.csv',
#  'data/index/spx/CITGQ UN Equity.csv',
#  'data/index/spx/CL UN Equity.csv',
#  'data/index/spx/CLF UN Equity.csv',
#  'data/index/spx/CLX UN Equity.csv',
#  'data/index/spx/CMA UN Equity.csv',
#  'data/index/spx/CMCSA UA Equity.csv',
#  'data/index/spx/CMCSA UQ Equity.csv',
#  'data/index/spx/CMCSA UW Equity.csv',
#  'data/index/spx/CMCSK UQ Equity.csv',
#  'data/index/spx/CMCSK UW Equity.csv',
#  'data/index/spx/CME UN Equity.csv',
#  'data/index/spx/CME UW Equity.csv',
#  'data/index/spx/CMG UN Equity.csv',
#  'data/index/spx/CMI UN Equity.csv',
#  'data/index/spx/CMS UN Equity.csv',
#  'data/index/spx/CMVT UQ Equity.csv',
#  'data/index/spx/CMX UN Equity.csv',
#  'data/index/spx/CNC UN Equity.csv',
#  'data/index/spx/CNP UN Equity.csv',
#  'data/index/spx/CNX UN Equity.csv',
#  'data/index/spx/COF UN Equity.csv',
#  'data/index/spx/COG UN Equity.csv',
#  'data/index/spx/COL UN Equity.csv',
#  'data/index/spx/COO UN Equity.csv',
#  'data/index/spx/COP UN Equity.csv',
#  'data/index/spx/COST UA Equity.csv',
#  'data/index/spx/COST UQ Equity.csv',
#  'data/index/spx/COST UW Equity.csv',
#  'data/index/spx/COTY UN Equity.csv',
#  'data/index/spx/COV UN Equity.csv',
#  'data/index/spx/CPB UN Equity.csv',
#  'data/index/spx/CPGX UN Equity.csv',
#  'data/index/spx/CPGX US Equity.csv',
#  'data/index/spx/CPNLQ UN Equity.csv',
#  'data/index/spx/CPPRQ UN Equity.csv',
#  'data/index/spx/CPRI UN Equity.csv',
#  'data/index/spx/CPRT UW Equity.csv',
#  'data/index/spx/CR UN Equity.csv',
#  'data/index/spx/CRM UN Equity.csv',
#  'data/index/spx/CSC UN Equity.csv',
#  'data/index/spx/CSCO UQ Equity.csv',
#  'data/index/spx/CSCO UW Equity.csv',
#  'data/index/spx/CSRA UN Equity.csv',
#  'data/index/spx/CSX UN Equity.csv',
#  'data/index/spx/CSX UW Equity.csv',
#  'data/index/spx/CTAS UQ Equity.csv',
#  'data/index/spx/CTAS UW Equity.csv',
#  'data/index/spx/CTB UN Equity.csv',
#  'data/index/spx/CTLT UN Equity.csv',
#  'data/index/spx/CTSH UW Equity.csv',
#  'data/index/spx/CTVA UN Equity.csv',
#  'data/index/spx/CTXS UQ Equity.csv',
#  'data/index/spx/CTXS UW Equity.csv',
#  'data/index/spx/CVC UN Equity.csv',
#  'data/index/spx/CVET UW Equity.csv',
#  'data/index/spx/CVG UN Equity.csv',
#  'data/index/spx/CVH UN Equity.csv',
#  'data/index/spx/CVH US Equity.csv',
#  'data/index/spx/CVS UN Equity.csv',
#  'data/index/spx/CVX UN Equity.csv',
#  'data/index/spx/CXO UN Equity.csv',
#  'data/index/spx/D UN Equity.csv',
#  'data/index/spx/DAL UN Equity.csv',
#  'data/index/spx/DALRQ UN Equity.csv',
#  'data/index/spx/DCNAQ UN Equity.csv',
#  'data/index/spx/DD UN Equity.csv',
#  'data/index/spx/DDS UN Equity.csv',
#  'data/index/spx/DE UN Equity.csv',
#  'data/index/spx/DFODQ UN Equity.csv',
#  'data/index/spx/DFS UN Equity.csv',
#  'data/index/spx/DG UN Equity.csv',
#  'data/index/spx/DGX UN Equity.csv',
#  'data/index/spx/DHI UN Equity.csv',
#  'data/index/spx/DHR UN Equity.csv',
#  'data/index/spx/DIS UN Equity.csv',
#  'data/index/spx/DISCA UW Equity.csv',
#  'data/index/spx/DISCK UW Equity.csv',
#  'data/index/spx/DISH UW Equity.csv',
#  'data/index/spx/DJ UN Equity.csv',
#  'data/index/spx/DLPH UN Equity.csv',
#  'data/index/spx/DLR UN Equity.csv',
#  'data/index/spx/DLTR UW Equity.csv',
#  'data/index/spx/DLX UN Equity.csv',
#  'data/index/spx/DNRCQ UN Equity.csv',
#  'data/index/spx/DOFSQ UN Equity.csv',
#  'data/index/spx/DOV UN Equity.csv',
#  'data/index/spx/DOW UN Equity.csv',
#  'data/index/spx/DPHIQ UN Equity.csv',
#  'data/index/spx/DPZ UN Equity.csv',
#  'data/index/spx/DRE UN Equity.csv',
#  'data/index/spx/DRI UN Equity.csv',
#  'data/index/spx/DTE UN Equity.csv',
#  'data/index/spx/DUK UN Equity.csv',
#  'data/index/spx/DVA UN Equity.csv',
#  'data/index/spx/DVMT UN Equity.csv',
#  'data/index/spx/DVN UA Equity.csv',
#  'data/index/spx/DVN UN Equity.csv',
#  'data/index/spx/DXC UN Equity.csv',
#  'data/index/spx/DXCM UW Equity.csv',
#  'data/index/spx/DYNIQ UN Equity.csv',
#  'data/index/spx/EA UQ Equity.csv',
#  'data/index/spx/EA UW Equity.csv',
#  'data/index/spx/EBAY UQ Equity.csv',
#  'data/index/spx/EBAY UW Equity.csv',
#  'data/index/spx/ECL UN Equity.csv',
#  'data/index/spx/ED UN Equity.csv',
#  'data/index/spx/EFX UN Equity.csv',
#  'data/index/spx/EHC UN Equity.csv',
#  'data/index/spx/EIX UN Equity.csv',
#  'data/index/spx/EKDKQ UN Equity.csv',
#  'data/index/spx/EL UN Equity.csv',
#  'data/index/spx/EMC UN Equity.csv',
#  'data/index/spx/EMN UN Equity.csv',
#  'data/index/spx/EMR UN Equity.csv',
#  'data/index/spx/ENDP UW Equity.csv',
#  'data/index/spx/EOG UN Equity.csv',
#  'data/index/spx/EOP UN Equity.csv',
#  'data/index/spx/EP UN Equity.csv',
#  'data/index/spx/EQIX UW Equity.csv',
#  'data/index/spx/EQR UN Equity.csv',
#  'data/index/spx/EQT UN Equity.csv',
#  'data/index/spx/ES UN Equity.csv',
#  'data/index/spx/ESRX UQ Equity.csv',
#  'data/index/spx/ESRX UW Equity.csv',
#  'data/index/spx/ESS UN Equity.csv',
#  'data/index/spx/ETFC UN Equity.csv',
#  'data/index/spx/ETFC US Equity.csv',
#  'data/index/spx/ETFC UW Equity.csv',
#  'data/index/spx/ETN UN Equity.csv',
#  'data/index/spx/ETR UN Equity.csv',
#  'data/index/spx/ETSY UW Equity.csv',
#  'data/index/spx/EVHC UN Equity.csv',
#  'data/index/spx/EVRG UN Equity.csv',
#  'data/index/spx/EW UN Equity.csv',
#  'data/index/spx/EXC UN Equity.csv',
#  'data/index/spx/EXC UW Equity.csv',
#  'data/index/spx/EXPD UW Equity.csv',
#  'data/index/spx/EXPE UW Equity.csv',
#  'data/index/spx/EXR UN Equity.csv',
#  'data/index/spx/F UN Equity.csv',
#  'data/index/spx/FANG UW Equity.csv',
#  'data/index/spx/FAST UW Equity.csv',
#  'data/index/spx/FB UW Equity.csv',
#  'data/index/spx/FBF UN Equity.csv',
#  'data/index/spx/FBHS UN Equity.csv',
#  'data/index/spx/FCX UN Equity.csv',
#  'data/index/spx/FDO UN Equity.csv',
#  'data/index/spx/FDX UN Equity.csv',
#  'data/index/spx/FE UN Equity.csv',
#  'data/index/spx/FFIV UW Equity.csv',
#  'data/index/spx/FHI UN Equity.csv',
#  'data/index/spx/FHN UN Equity.csv',
#  'data/index/spx/FIS UN Equity.csv',
#  'data/index/spx/FISV UQ Equity.csv',
#  'data/index/spx/FISV UW Equity.csv',
#  'data/index/spx/FITB UQ Equity.csv',
#  'data/index/spx/FITB UW Equity.csv',
#  'data/index/spx/FL UN Equity.csv',
#  'data/index/spx/FLIR UW Equity.csv',
#  'data/index/spx/FLR UN Equity.csv',
#  'data/index/spx/FLS UN Equity.csv',
#  'data/index/spx/FLT UN Equity.csv',
#  'data/index/spx/FMC UN Equity.csv',
#  'data/index/spx/FMCC UN Equity.csv',
#  'data/index/spx/FNMA UN Equity.csv',
#  'data/index/spx/FOSL UW Equity.csv',
#  'data/index/spx/FOX UW Equity.csv',
#  'data/index/spx/FOXA UW Equity.csv',
#  'data/index/spx/FRC UN Equity.csv',
#  'data/index/spx/FRT UN Equity.csv',
#  'data/index/spx/FSH UN Equity.csv',
#  'data/index/spx/FSL B UN Equity.csv',
#  'data/index/spx/FSLR UW Equity.csv',
#  'data/index/spx/FTI UN Equity.csv',
#  'data/index/spx/FTNT UW Equity.csv',
#  'data/index/spx/FTRCQ UN Equity.csv',
#  'data/index/spx/FTRCQ UW Equity.csv',
#  'data/index/spx/FTV UN Equity.csv',
#  'data/index/spx/GAS UN Equity.csv',
#  'data/index/spx/GD UN Equity.csv',
#  'data/index/spx/GDT UN Equity.csv',
#  'data/index/spx/GDW UN Equity.csv',
#  'data/index/spx/GE UN Equity.csv',
#  'data/index/spx/GENZ UA Equity.csv',
#  'data/index/spx/GENZ UQ Equity.csv',
#  'data/index/spx/GENZ UW Equity.csv',
#  'data/index/spx/GGP UN Equity.csv',
#  'data/index/spx/GGP UP Equity.csv',
#  'data/index/spx/GHC UN Equity.csv',
#  'data/index/spx/GILD UQ Equity.csv',
#  'data/index/spx/GILD UW Equity.csv',
#  'data/index/spx/GIS UN Equity.csv',
#  'data/index/spx/GL UN Equity.csv',
#  'data/index/spx/GLW UN Equity.csv',
#  'data/index/spx/GM UN Equity.csv',
#  'data/index/spx/GMCR UW Equity.csv',
#  'data/index/spx/GME UN Equity.csv',
#  'data/index/spx/GNW UN Equity.csv',
#  'data/index/spx/GNW UP Equity.csv',
#  'data/index/spx/GOOG UW Equity.csv',
#  'data/index/spx/GOOGL UQ Equity.csv',
#  'data/index/spx/GOOGL UW Equity.csv',
#  'data/index/spx/GPC UN Equity.csv',
#  'data/index/spx/GPN UN Equity.csv',
#  'data/index/spx/GPS UN Equity.csv',
#  'data/index/spx/GR UN Equity.csv',
#  'data/index/spx/GR US Equity.csv',
#  'data/index/spx/GRMN UW Equity.csv',
#  'data/index/spx/GS UN Equity.csv',
#  'data/index/spx/GT UN Equity.csv',
#  'data/index/spx/GT UW Equity.csv',
#  'data/index/spx/GTGOF US Equity.csv',
#  'data/index/spx/GTW UN Equity.csv',
#  'data/index/spx/GTXMQ UN Equity.csv',
#  'data/index/spx/GWW UN Equity.csv',
#  'data/index/spx/HAL UN Equity.csv',
#  'data/index/spx/HAR UN Equity.csv',
#  'data/index/spx/HAR US Equity.csv',
#  'data/index/spx/HAS US Equity.csv',
#  'data/index/spx/HAS UW Equity.csv',
#  'data/index/spx/HBAN UA Equity.csv',
#  'data/index/spx/HBAN UQ Equity.csv',
#  'data/index/spx/HBAN UW Equity.csv',
#  'data/index/spx/HBI UN Equity.csv',
#  'data/index/spx/HCA UN Equity.csv',
#  'data/index/spx/HCBK UW Equity.csv',
#  'data/index/spx/HD UN Equity.csv',
#  'data/index/spx/HES UN Equity.csv',
#  'data/index/spx/HET UN Equity.csv',
#  'data/index/spx/HFC UN Equity.csv',
#  'data/index/spx/HIG UN Equity.csv',
#  'data/index/spx/HII UN Equity.csv',
#  'data/index/spx/HLT UN Equity.csv',
#  'data/index/spx/HMA UN Equity.csv',
#  'data/index/spx/HNZ UN Equity.csv',
#  'data/index/spx/HOG UN Equity.csv',
#  'data/index/spx/HOLX UW Equity.csv',
#  'data/index/spx/HON UN Equity.csv',
#  'data/index/spx/HOT UN Equity.csv',
#  'data/index/spx/HP UN Equity.csv',
#  'data/index/spx/HPC US Equity.csv',
#  'data/index/spx/HPE UN Equity.csv',
#  'data/index/spx/HPQ UN Equity.csv',
#  'data/index/spx/HRB UN Equity.csv',
#  'data/index/spx/HRL UN Equity.csv',
#  'data/index/spx/HSH UN Equity.csv',
#  'data/index/spx/HSIC UW Equity.csv',
#  'data/index/spx/HSP UN Equity.csv',
#  'data/index/spx/HST UN Equity.csv',
#  'data/index/spx/HST UW Equity.csv',
#  'data/index/spx/HSY UN Equity.csv',
#  'data/index/spx/HUM UN Equity.csv',
#  'data/index/spx/HWM UN Equity.csv',
#  'data/index/spx/IBM UN Equity.csv',
#  'data/index/spx/ICE UN Equity.csv',
#  'data/index/spx/IDXX UW Equity.csv',
#  'data/index/spx/IEX UN Equity.csv',
#  'data/index/spx/IFF UN Equity.csv',
#  'data/index/spx/IILGV UQ Equity.csv',
#  'data/index/spx/ILMN UW Equity.csv',
#  'data/index/spx/INCY UW Equity.csv',
#  'data/index/spx/INFO UN Equity.csv',
#  'data/index/spx/INFO UW Equity.csv',
#  'data/index/spx/INTC UQ Equity.csv',
#  'data/index/spx/INTC UW Equity.csv',
#  'data/index/spx/INTU UQ Equity.csv',
#  'data/index/spx/INTU UW Equity.csv',
#  'data/index/spx/IP UN Equity.csv',
#  'data/index/spx/IPG UN Equity.csv',
#  'data/index/spx/IPGP UW Equity.csv',
#  'data/index/spx/IQV UN Equity.csv',
#  'data/index/spx/IR UN Equity.csv',
#  'data/index/spx/IRM UN Equity.csv',
#  'data/index/spx/ISRG UW Equity.csv',
#  'data/index/spx/IT UN Equity.csv',
#  'data/index/spx/ITT UN Equity.csv',
#  'data/index/spx/ITW UN Equity.csv',
#  'data/index/spx/IVZ UN Equity.csv',
#  'data/index/spx/J UN Equity.csv',
#  'data/index/spx/JAVA UQ Equity.csv',
#  'data/index/spx/JAVA UW Equity.csv',
#  'data/index/spx/JBGS UN Equity.csv',
#  'data/index/spx/JBHT UW Equity.csv',
#  'data/index/spx/JBL UN Equity.csv',
#  'data/index/spx/JCI UN Equity.csv',
#  'data/index/spx/JEF UN Equity.csv',
#  'data/index/spx/JHF UN Equity.csv',
#  'data/index/spx/JKHY UW Equity.csv',
#  'data/index/spx/JNJ UN Equity.csv',
#  'data/index/spx/JNPR UN Equity.csv',
#  'data/index/spx/JNPR UQ Equity.csv',
#  'data/index/spx/JNPR UW Equity.csv',
#  'data/index/spx/JNS UN Equity.csv',
#  'data/index/spx/JNY UN Equity.csv',
#  'data/index/spx/JOY UN Equity.csv',
#  'data/index/spx/JOY UW Equity.csv',
#  'data/index/spx/JPM UN Equity.csv',
#  'data/index/spx/JWN UN Equity.csv',
#  'data/index/spx/K UN Equity.csv',
#  'data/index/spx/KATE UN Equity.csv',
#  'data/index/spx/KBH UN Equity.csv',
#  'data/index/spx/KDP UN Equity.csv',
#  'data/index/spx/KEY UN Equity.csv',
#  'data/index/spx/KEYS UN Equity.csv',
#  'data/index/spx/KG UN Equity.csv',
#  'data/index/spx/KHC UW Equity.csv',
#  'data/index/spx/KIM UN Equity.csv',
#  'data/index/spx/KLAC UQ Equity.csv',
#  'data/index/spx/KLAC UW Equity.csv',
#  'data/index/spx/KMB UN Equity.csv',
#  'data/index/spx/KMI UN Equity.csv',
#  'data/index/spx/KMX UN Equity.csv',
#  'data/index/spx/KO UN Equity.csv',
#  'data/index/spx/KR UN Equity.csv',
#  'data/index/spx/KRB UN Equity.csv',
#  'data/index/spx/KRFT UW Equity.csv',
#  'data/index/spx/KRI UN Equity.csv',
#  'data/index/spx/KSE UN Equity.csv',
#  'data/index/spx/KSS UN Equity.csv',
#  'data/index/spx/KSU UN Equity.csv',
#  'data/index/spx/KTB UN Equity.csv',
#  'data/index/spx/L UN Equity.csv',
#  'data/index/spx/LB UN Equity.csv',
#  'data/index/spx/LDOS UN Equity.csv',
#  'data/index/spx/LEG UN Equity.csv',
#  'data/index/spx/LEHMQ UN Equity.csv',
#  'data/index/spx/LEHMQ UP Equity.csv',
#  'data/index/spx/LEN B UN Equity.csv',
#  'data/index/spx/LEN UN Equity.csv',
#  'data/index/spx/LH UN Equity.csv',
#  'data/index/spx/LHX UN Equity.csv',
#  'data/index/spx/LIN UN Equity.csv',
#  'data/index/spx/LKQ UW Equity.csv',
#  'data/index/spx/LLL UN Equity.csv',
#  'data/index/spx/LLTC UQ Equity.csv',
#  'data/index/spx/LLTC UW Equity.csv',
#  'data/index/spx/LLY UN Equity.csv',
#  'data/index/spx/LM UN Equity.csv',
#  'data/index/spx/LMT UN Equity.csv',
#  'data/index/spx/LNC UN Equity.csv',
#  'data/index/spx/LNT UN Equity.csv',
#  'data/index/spx/LNT UW Equity.csv',
#  'data/index/spx/LO UN Equity.csv',
#  'data/index/spx/LOW UN Equity.csv',
#  'data/index/spx/LPX UN Equity.csv',
#  'data/index/spx/LRCX UW Equity.csv',
#  'data/index/spx/LUMN UN Equity.csv',
#  'data/index/spx/LUV UN Equity.csv',
#  'data/index/spx/LVLT UN Equity.csv',
#  'data/index/spx/LVS UN Equity.csv',
#  'data/index/spx/LW UN Equity.csv',
#  'data/index/spx/LXK UN Equity.csv',
#  'data/index/spx/LYB UN Equity.csv',
#  'data/index/spx/LYV UN Equity.csv',
#  'data/index/spx/M UN Equity.csv',
#  'data/index/spx/MA UN Equity.csv',
#  'data/index/spx/MAA UN Equity.csv',
#  'data/index/spx/MAC UN Equity.csv',
#  'data/index/spx/MAR UN Equity.csv',
#  'data/index/spx/MAR UW Equity.csv',
#  'data/index/spx/MAS UN Equity.csv',
#  'data/index/spx/MAT UN Equity.csv',
#  'data/index/spx/MAT US Equity.csv',
#  'data/index/spx/MAT UW Equity.csv',
#  'data/index/spx/MBI UN Equity.csv',
#  'data/index/spx/MCD UN Equity.csv',
#  'data/index/spx/MCHP UW Equity.csv',
#  'data/index/spx/MCK UN Equity.csv',
#  'data/index/spx/MCO UN Equity.csv',
#  'data/index/spx/MDLZ UN Equity.csv',
#  'data/index/spx/MDLZ UW Equity.csv',
#  'data/index/spx/MDP UN Equity.csv',
#  'data/index/spx/MDRIQ UN Equity.csv',
#  'data/index/spx/MDT UN Equity.csv',
#  'data/index/spx/MEDI UQ Equity.csv',
#  'data/index/spx/MEDI UW Equity.csv',
#  'data/index/spx/MEE UN Equity.csv',
#  'data/index/spx/MEL UN Equity.csv',
#  'data/index/spx/MER UN Equity.csv',
#  'data/index/spx/MERQ UQ Equity.csv',
#  'data/index/spx/MET UN Equity.csv',
#  'data/index/spx/MFE UN Equity.csv',
#  'data/index/spx/MGM UN Equity.csv',
#  'data/index/spx/MHK UN Equity.csv',
#  'data/index/spx/MHS UN Equity.csv',
#  'data/index/spx/MHS US Equity.csv',
#  'data/index/spx/MI UN Equity.csv',
#  'data/index/spx/MIRKQ UN Equity.csv',
#  'data/index/spx/MJN UN Equity.csv',
#  'data/index/spx/MJN US Equity.csv',
#  'data/index/spx/MJN-W UN Equity.csv',
#  'data/index/spx/MKC UN Equity.csv',
#  'data/index/spx/MKTX UW Equity.csv',
#  'data/index/spx/MLM UN Equity.csv',
#  'data/index/spx/MMC UN Equity.csv',
#  'data/index/spx/MMM UN Equity.csv',
#  'data/index/spx/MNKKQ UN Equity.csv',
#  'data/index/spx/MNST UW Equity.csv',
#  'data/index/spx/MO UN Equity.csv',
#  'data/index/spx/MOLX UQ Equity.csv',
#  'data/index/spx/MOLX UW Equity.csv',
#  'data/index/spx/MOS UN Equity.csv',
#  'data/index/spx/MPC UN Equity.csv',
#  'data/index/spx/MRK UN Equity.csv',
#  'data/index/spx/MRO UN Equity.csv',
#  'data/index/spx/MS UN Equity.csv',
#  'data/index/spx/MSCI UN Equity.csv',
#  'data/index/spx/MSFT UQ Equity.csv',
#  'data/index/spx/MSFT UW Equity.csv',
#  'data/index/spx/MSI UN Equity.csv',
#  'data/index/spx/MTB UN Equity.csv',
#  'data/index/spx/MTD UN Equity.csv',
#  'data/index/spx/MTG UN Equity.csv',
#  'data/index/spx/MTLQQ UN Equity.csv',
#  'data/index/spx/MTW UN Equity.csv',
#  'data/index/spx/MU UN Equity.csv',
#  'data/index/spx/MU UW Equity.csv',
#  'data/index/spx/MUR UN Equity.csv',
#  'data/index/spx/MWV UN Equity.csv',
#  'data/index/spx/MWW UN Equity.csv',
#  'data/index/spx/MWW UQ Equity.csv',
#  'data/index/spx/MWW UW Equity.csv',
#  'data/index/spx/MXIM UQ Equity.csv',
#  'data/index/spx/MXIM UW Equity.csv',
#  'data/index/spx/MYL UN Equity.csv',
#  'data/index/spx/MYL UW Equity.csv',
#  'data/index/spx/NAV UN Equity.csv',
#  'data/index/spx/NAVI UW Equity.csv',
#  'data/index/spx/NBL UN Equity.csv',
#  'data/index/spx/NBL US Equity.csv',
#  'data/index/spx/NBL UW Equity.csv',
#  'data/index/spx/NBR UA Equity.csv',
#  'data/index/spx/NBR UN Equity.csv',
#  'data/index/spx/NCC UN Equity.csv',
#  'data/index/spx/NCLH UN Equity.csv',
#  'data/index/spx/NCLH UW Equity.csv',
#  'data/index/spx/NCR UN Equity.csv',
#  'data/index/spx/NDAQ UW Equity.csv',
#  'data/index/spx/NEBLQ UN Equity.csv',
#  'data/index/spx/NEE UN Equity.csv',
#  'data/index/spx/NEM UN Equity.csv',
#  'data/index/spx/NFB UN Equity.csv',
#  'data/index/spx/NFLX UW Equity.csv',
#  'data/index/spx/NFX UN Equity.csv',
#  'data/index/spx/NGVT UN Equity.csv',
#  'data/index/spx/NI UN Equity.csv',
#  'data/index/spx/NKE UN Equity.csv',
#  'data/index/spx/NKTR UW Equity.csv',
#  'data/index/spx/NLOK UQ Equity.csv',
#  'data/index/spx/NLOK UW Equity.csv',
#  'data/index/spx/NLSN UN Equity.csv',
#  'data/index/spx/NOC UN Equity.csv',
#  'data/index/spx/NOV UN Equity.csv',
#  'data/index/spx/NOVL UQ Equity.csv',
#  'data/index/spx/NOVL UW Equity.csv',
#  'data/index/spx/NOW UN Equity.csv',
#  'data/index/spx/NRG UN Equity.csv',
#  'data/index/spx/NSC UN Equity.csv',
#  'data/index/spx/NTAP UQ Equity.csv',
#  'data/index/spx/NTAP UW Equity.csv',
#  'data/index/spx/NTRS UQ Equity.csv',
#  'data/index/spx/NTRS UW Equity.csv',
#  'data/index/spx/NUE UN Equity.csv',
#  'data/index/spx/NVDA UA Equity.csv',
#  'data/index/spx/NVDA UQ Equity.csv',
#  'data/index/spx/NVDA UW Equity.csv',
#  'data/index/spx/NVR UN Equity.csv',
#  'data/index/spx/NVT UN Equity.csv',
#  'data/index/spx/NWL UN Equity.csv',
#  'data/index/spx/NWL UW Equity.csv',
#  'data/index/spx/NWS UW Equity.csv',
#  'data/index/spx/NWSA UW Equity.csv',
#  'data/index/spx/NXTL UQ Equity.csv',
#  'data/index/spx/NYT UN Equity.csv',
#  'data/index/spx/NYX UN Equity.csv',
#  'data/index/spx/O UN Equity.csv',
#  'data/index/spx/ODFL UW Equity.csv',
#  'data/index/spx/OI UN Equity.csv',
#  'data/index/spx/OKE UN Equity.csv',
#  'data/index/spx/OMC UN Equity.csv',
#  'data/index/spx/OMX UN Equity.csv',
#  'data/index/spx/ORCL UN Equity.csv',
#  'data/index/spx/ORCL UQ Equity.csv',
#  'data/index/spx/ORCL UW Equity.csv',
#  'data/index/spx/ORLY UW Equity.csv',
#  'data/index/spx/OTIS UN Equity.csv',
#  'data/index/spx/OXY UN Equity.csv',
#  'data/index/spx/PAYC UN Equity.csv',
#  'data/index/spx/PAYX UQ Equity.csv',
#  'data/index/spx/PAYX UW Equity.csv',
#  'data/index/spx/PBCT UW Equity.csv',
#  'data/index/spx/PBG UN Equity.csv',
#  'data/index/spx/PBI UN Equity.csv',
#  'data/index/spx/PCAR UQ Equity.csv',
#  'data/index/spx/PCAR UW Equity.csv',
#  'data/index/spx/PCG UN Equity.csv',
#  'data/index/spx/PCL UN Equity.csv',
#  'data/index/spx/PCP UN Equity.csv',
#  'data/index/spx/PDCO UQ Equity.csv',
#  'data/index/spx/PDCO UW Equity.csv',
#  'data/index/spx/PEAK UN Equity.csv',
#  'data/index/spx/PEG UN Equity.csv',
#  'data/index/spx/PEP UN Equity.csv',
#  'data/index/spx/PEP UW Equity.csv',
#  'data/index/spx/PETM UW Equity.csv',
#  'data/index/spx/PFE UN Equity.csv',
#  'data/index/spx/PFG UN Equity.csv',
#  'data/index/spx/PFG UW Equity.csv',
#  'data/index/spx/PG UN Equity.csv',
#  'data/index/spx/PGL UN Equity.csv',
#  'data/index/spx/PGR UN Equity.csv',
#  'data/index/spx/PH UN Equity.csv',
#  'data/index/spx/PHM UN Equity.csv',
#  'data/index/spx/PKG UN Equity.csv',
#  'data/index/spx/PKI UN Equity.csv',
#  'data/index/spx/PLD UN Equity.csv',
#  'data/index/spx/PM UN Equity.csv',
#  'data/index/spx/PMCS UQ Equity.csv',
#  'data/index/spx/PMCS UW Equity.csv',
#  'data/index/spx/PNC UN Equity.csv',
#  'data/index/spx/PNR UN Equity.csv',
#  'data/index/spx/PNW UN Equity.csv',
#  'data/index/spx/POM UN Equity.csv',
#  'data/index/spx/POM US Equity.csv',
#  'data/index/spx/POOL UW Equity.csv',
#  'data/index/spx/PPG UN Equity.csv',
#  'data/index/spx/PPL UN Equity.csv',
#  'data/index/spx/PRGO UN Equity.csv',
#  'data/index/spx/PRGO UW Equity.csv',
#  'data/index/spx/PRSP UN Equity.csv',
#  'data/index/spx/PRU UN Equity.csv',
#  'data/index/spx/PSA UN Equity.csv',
#  'data/index/spx/PSX UN Equity.csv',
#  'data/index/spx/PTC UQ Equity.csv',
#  'data/index/spx/PTC UW Equity.csv',
#  'data/index/spx/PTV UN Equity.csv',
#  'data/index/spx/PVH UN Equity.csv',
#  'data/index/spx/PVN UN Equity.csv',
#  'data/index/spx/PWER UQ Equity.csv',
#  'data/index/spx/PWR UN Equity.csv',
#  'data/index/spx/PX UN Equity.csv',
#  'data/index/spx/PXD UN Equity.csv',
#  'data/index/spx/PYPL UW Equity.csv',
#  'data/index/spx/QCOM UQ Equity.csv',
#  'data/index/spx/QCOM UW Equity.csv',
#  'data/index/spx/QCP UN Equity.csv',
#  'data/index/spx/QEP UN Equity.csv',
#  'data/index/spx/QLGC UQ Equity.csv',
#  'data/index/spx/QLGC UW Equity.csv',
#  'data/index/spx/QRVO UW Equity.csv',
#  'data/index/spx/QTRN UQ Equity.csv',
#  'data/index/spx/R UN Equity.csv',
#  'data/index/spx/RAI UN Equity.csv',
#  'data/index/spx/RATL UQ Equity.csv',
#  'data/index/spx/RBK UN Equity.csv',
#  'data/index/spx/RCL UN Equity.csv',
#  'data/index/spx/RDC UN Equity.csv',
#  'data/index/spx/RE UN Equity.csv',
#  'data/index/spx/REG UN Equity.csv',
#  'data/index/spx/REG UW Equity.csv',
#  'data/index/spx/REGN UW Equity.csv',
#  'data/index/spx/REZI UN Equity.csv',
#  'data/index/spx/RF UN Equity.csv',
#  'data/index/spx/RHI UN Equity.csv',
#  'data/index/spx/RHT UN Equity.csv',
#  'data/index/spx/RHT US Equity.csv',
#  'data/index/spx/RIG UN Equity.csv',
#  'data/index/spx/RJF UN Equity.csv',
#  'data/index/spx/RL UN Equity.csv',
#  'data/index/spx/RMD UN Equity.csv',
#  'data/index/spx/ROH UN Equity.csv',
#  'data/index/spx/ROK UN Equity.csv',
#  'data/index/spx/ROL UN Equity.csv',
#  'data/index/spx/ROP UN Equity.csv',
#  'data/index/spx/ROST UW Equity.csv',
#  'data/index/spx/RRC UN Equity.csv',
#  'data/index/spx/RRD UN Equity.csv',
#  'data/index/spx/RRD UW Equity.csv',
#  'data/index/spx/RSG UN Equity.csv',
#  'data/index/spx/RSHCQ UN Equity.csv',
#  'data/index/spx/RTN UN Equity.csv',
#  'data/index/spx/RTX UN Equity.csv',
#  'data/index/spx/RX UN Equity.csv',
#  'data/index/spx/SANM UQ Equity.csv',
#  'data/index/spx/SANM UW Equity.csv',
#  'data/index/spx/SBAC UW Equity.csv',
#  'data/index/spx/SBUX UA Equity.csv',
#  'data/index/spx/SBUX UQ Equity.csv',
#  'data/index/spx/SBUX UW Equity.csv',
#  'data/index/spx/SCG UN Equity.csv',
#  'data/index/spx/SCHW UN Equity.csv',
#  'data/index/spx/SCHW UQ Equity.csv',
#  'data/index/spx/SCHW UW Equity.csv',
#  'data/index/spx/SEBL UA Equity.csv',
#  'data/index/spx/SEBL UQ Equity.csv',
#  'data/index/spx/SEE UN Equity.csv',
#  'data/index/spx/SGP UN Equity.csv',
#  'data/index/spx/SHLDQ UQ Equity.csv',
#  'data/index/spx/SHLDQ UW Equity.csv',
#  'data/index/spx/SHW UN Equity.csv',
#  'data/index/spx/SIAL UQ Equity.csv',
#  'data/index/spx/SIAL UW Equity.csv',
#  'data/index/spx/SIG UN Equity.csv',
#  'data/index/spx/SITC UN Equity.csv',
#  'data/index/spx/SIVB UW Equity.csv',
#  'data/index/spx/SJM UN Equity.csv',
#  'data/index/spx/SLB UN Equity.csv',
#  'data/index/spx/SLG UN Equity.csv',
#  'data/index/spx/SLM UN Equity.csv',
#  'data/index/spx/SLM UQ Equity.csv',
#  'data/index/spx/SLM UW Equity.csv',
#  'data/index/spx/SNA UN Equity.csv',
#  'data/index/spx/SNDK UQ Equity.csv',
#  'data/index/spx/SNDK UW Equity.csv',
#  'data/index/spx/SNI UN Equity.csv',
#  'data/index/spx/SNI UW Equity.csv',
#  'data/index/spx/SNPS UW Equity.csv',
#  'data/index/spx/SNV UN Equity.csv',
#  'data/index/spx/SO UN Equity.csv',
#  'data/index/spx/SOV UN Equity.csv',
#  'data/index/spx/SPG UN Equity.csv',
#  'data/index/spx/SPGI UN Equity.csv',
#  'data/index/spx/SPLS UA Equity.csv',
#  'data/index/spx/SPLS UQ Equity.csv',
#  'data/index/spx/SPLS US Equity.csv',
#  'data/index/spx/SPLS UW Equity.csv',
#  'data/index/spx/SRCL UW Equity.csv',
#  'data/index/spx/SRE UN Equity.csv',
#  'data/index/spx/SSP UN Equity.csv',
#  'data/index/spx/STE UN Equity.csv',
#  'data/index/spx/STI UN Equity.csv',
#  'data/index/spx/STJ UN Equity.csv',
#  'data/index/spx/STR UN Equity.csv',
#  'data/index/spx/STT UN Equity.csv',
#  'data/index/spx/STX UW Equity.csv',
#  'data/index/spx/STZ UN Equity.csv',
#  'data/index/spx/SUNEQ UN Equity.csv',
#  'data/index/spx/SVU UN Equity.csv',
#  'data/index/spx/SWK UN Equity.csv',
#  'data/index/spx/SWKS UW Equity.csv',
#  'data/index/spx/SWN UN Equity.csv',
#  'data/index/spx/SWY UN Equity.csv',
#  'data/index/spx/SYF UN Equity.csv',
#  'data/index/spx/SYK UN Equity.csv',
#  'data/index/spx/SYY UN Equity.csv',
#  'data/index/spx/T UN Equity.csv',
#  'data/index/spx/TAP B UN Equity.csv',
#  'data/index/spx/TAP UN Equity.csv',
#  'data/index/spx/TDC UN Equity.csv',
#  'data/index/spx/TDG UN Equity.csv',
#  'data/index/spx/TDY UN Equity.csv',
#  'data/index/spx/TEG UN Equity.csv',
#  'data/index/spx/TEK UN Equity.csv',
#  'data/index/spx/TEL UN Equity.csv',
#  'data/index/spx/TER UN Equity.csv',
#  'data/index/spx/TER UW Equity.csv',
#  'data/index/spx/TEX UN Equity.csv',
#  'data/index/spx/TFC UN Equity.csv',
#  'data/index/spx/TFCF UW Equity.csv',
#  'data/index/spx/TFCFA UN Equity.csv',
#  'data/index/spx/TFCFA UW Equity.csv',
#  'data/index/spx/TFX UN Equity.csv',
#  'data/index/spx/TGNA UN Equity.csv',
#  'data/index/spx/TGT UN Equity.csv',
#  'data/index/spx/THC UN Equity.csv',
#  'data/index/spx/TIE UN Equity.csv',
#  'data/index/spx/TIF UN Equity.csv',
#  'data/index/spx/TIN UN Equity.csv',
#  'data/index/spx/TJX UN Equity.csv',
#  'data/index/spx/TLAB UQ Equity.csv',
#  'data/index/spx/TLAB UW Equity.csv',
#  'data/index/spx/TMO UN Equity.csv',
#  'data/index/spx/TMUS UN Equity.csv',
#  'data/index/spx/TMUS UW Equity.csv',
#  'data/index/spx/TNB UN Equity.csv',
#  'data/index/spx/TNL UN Equity.csv',
#  'data/index/spx/TOY UN Equity.csv',
#  'data/index/spx/TPR UN Equity.csv',
#  'data/index/spx/TRB UN Equity.csv',
#  'data/index/spx/TRIP UW Equity.csv',
#  'data/index/spx/TROW UQ Equity.csv',
#  'data/index/spx/TROW UW Equity.csv',
#  'data/index/spx/TRV UN Equity.csv',
#  'data/index/spx/TSCO UW Equity.csv',
#  'data/index/spx/TSLA UW Equity.csv',
#  'data/index/spx/TSN UN Equity.csv',
#  'data/index/spx/TSS UN Equity.csv',
#  'data/index/spx/TSS US Equity.csv',
#  'data/index/spx/TT UN Equity.csv',
#  'data/index/spx/TTWO UW Equity.csv',
#  'data/index/spx/TUP UN Equity.csv',
#  ...]

# %%
for n in names:
    name1 = n 
    name2 = n.replace("(1)","")
    a = pd.read_csv(name1)
    b = pd.read_csv(name2)
    print(n,"DIFF ->", np.sum(a.values != b.values))
# Out:
# data/index/spx/1448062D UW Equity(1).csv DIFF -> 1
# data/index/spx/2999130Q UN Equity(1).csv DIFF -> 1
# data/index/spx/ABKFQ UN Equity(1).csv DIFF -> 1
# data/index/spx/AN UN Equity(1).csv DIFF -> 1
# data/index/spx/AZO UN Equity(1).csv DIFF -> 1
# data/index/spx/COO UN Equity(1).csv DIFF -> 1
# data/index/spx/DPHIQ UN Equity(1).csv DIFF -> 1
# data/index/spx/QCP UN Equity(1).csv DIFF -> 1
# data/index/spx/TER UN Equity(1).csv DIFF -> 1

# %% [markdown]
# ## Variables

# %%
N_ITER = 500
N_SPLITS = 5
N_JOBS = 2

# %% [markdown]
# ## Get selected features

# %%
ticker_name =  "AMZN US Equity"
method = "sfi"
out_folder = "nasdaq"
score_path = "results/{}/{}/{}.csv".format(method,out_folder,ticker_name)
scores =  pd.read_csv(score_path)
cut = scores.feature_score.mean()
scores = (scores.loc[scores.feature_score > cut]).feature.to_list()

# %% [markdown]
# ## Get merged dataframe

# %%
ticker_path = "data/crsp/{}/{}.csv".format(out_folder,ticker_name)
train, test = merge_market_and_gtrends(ticker_path, test_size=0.5)

# %%
train.shape, test.shape
# Out:
# ((2087, 183), (2087, 183))

# %%
words = train.drop("target_return",1).columns.to_list()

add_shift(merged_df=train, words=words, max_lag=20)
train = train[["target_return"] + scores]
train = train.fillna(0)

add_shift(merged_df=test, words=words, max_lag=20)
test = test[["target_return"] + scores]
test = test.fillna(0)
# Out:
# add shift: 100%|██████████| 182/182 [01:01<00:00,  2.96it/s]
# add shift: 100%|██████████| 182/182 [00:55<00:00,  3.26it/s]

# %%
train.shape, test.shape
# Out:
# ((2087, 2006), (2087, 2006))

# %%
results = {"train":[],
           "test":[],
           "model":[]}

# %%
X_train = train.drop("target_return",1).values
y_train = train.target_return.values

X_test = test.drop("target_return",1).values
y_test = test.target_return.values

rf = RandomForestRegressor(n_estimators=100, n_jobs=2)
rf = rf.fit(X_train, y_train)

pred_train = rf.predict(X_train)
pred_test = rf.predict(X_test)

r2_train = new_r2(y_train, pred_train)
r2_test = new_r2(y_test, pred_test)

results["train"].append(r2_train)
results["test"].append(r2_test)
results["model"].append("Default Random Forest")

result = pd.DataFrame(results).set_index("model").sort_values("test", ascending=False).to_html()
display(HTML(result))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>train</th>
#       <th>test</th>
#     </tr>
#     <tr>
#       <th>model</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Default Random Forest</th>
#       <td>0.850046</td>
#       <td>-0.0589</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Random Forest

# %%
time_split = TimeSeriesSplit(n_splits=N_SPLITS)
r2_scorer = make_scorer(new_r2)
n_columns = X_train.shape[1]
rf_params =  {"max_features":list(range(1, int(np.sqrt(n_columns)+1))),
              "n_estimators": list(range(2, 60)),
              "max_depth": list(range(2, 21))}

rf_search = RandomizedSearchCV(estimator=RandomForestRegressor(),
                               param_distributions=rf_params,
                               n_iter=N_ITER,
                               cv=time_split,
                               verbose=1,
                               n_jobs=N_JOBS,
                               scoring=r2_scorer)

rf_search = rf_search.fit(X_train,y_train)
rf_train_pred  = rf_search.best_estimator_.predict(X_train)
rf_test_pred  = rf_search.best_estimator_.predict(X_test)

r2_train = new_r2(y_train, rf_train_pred)
r2_test = new_r2(y_test, rf_test_pred)

results["train"].append(r2_train)
results["test"].append(r2_test)
results["model"].append("Tunned Random Forest")

result = pd.DataFrame(results).set_index("model").sort_values("test", ascending=False).to_html()
display(HTML(result))
print(rf_search.best_params_)
# Out:
# Fitting 5 folds for each of 500 candidates, totalling 2500 fits
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  88 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=2)]: Done 380 tasks      | elapsed:   49.3s
# [Parallel(n_jobs=2)]: Done 672 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=2)]: Done 1336 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=2)]: Done 1844 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=2)]: Done 2432 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=2)]: Done 2500 out of 2500 | elapsed:  6.1min finished
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>train</th>
#       <th>test</th>
#     </tr>
#     <tr>
#       <th>model</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Tunned Random Forest</th>
#       <td>0.491416</td>
#       <td>-0.006191</td>
#     </tr>
#     <tr>
#       <th>Tunned Random Forest</th>
#       <td>0.375408</td>
#       <td>-0.009447</td>
#     </tr>
#     <tr>
#       <th>Default Random Forest</th>
#       <td>0.850046</td>
#       <td>-0.058900</td>
#     </tr>
#   </tbody>
# </table>
# {'n_estimators': 42, 'max_features': 33, 'max_depth': 10}
